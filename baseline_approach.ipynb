# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.datasets import make_regression
from xgboost import XGBRegressor
from matplotlib import pyplot
# %matplotlib inline 
from matplotlib import pyplot as plt
from matplotlib import style
import seaborn as sns
import string
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/Users/dennis/kaggle/input/predictive_maintenance/pump_data.csv', sep=';', low_memory=False , decimal=',')

# %%
df.head()
# Out:
#    Unnamed: 0            Date 03:I3SROE 03:T3362 03:PI3061A 03:PI3061B  \
# 0           0  01.01.19 00:00   890,187   77,923      3,025      3,043
# 1           1  01.01.19 00:10   890,262   77,893      3,024      3,043
# 2           2  01.01.19 00:20   890,337   77,863      3,024      3,043
# 3           3  01.01.19 00:30   890,294   77,833      3,023      3,043
# 4           4  01.01.19 00:40   890,239   77,823      3,023      3,043
#
#   03:PI3061C 03:PD3066 03:T3492 03:T3358  ... 03:E3851 03:T3632 03:T3633  \
# 0      3,055   No Data   40,456   97,602  ...    0,156    16,62   16,661
# 1      3,053   No Data   40,415   97,178  ...    0,157   16,675   16,676
# 2      3,051   No Data   40,375   97,215  ...    0,158   16,711   16,726
# 3      3,051   No Data    40,41   97,602  ...    0,159   16,716   16,784
# 4      3,052   No Data    40,41   97,438  ...     0,16    16,75   16,815
#
#   03:T3634 03:FC3195 03:FV3195 03:FC3197 03:FV3197 03:FC3199 03:FV3199
# 0   13,997   358,322       100    362,52       100    392,51       100
# 1   13,985   358,897       100   362,505       100   393,009       100
# 2    14,02   358,984       100   362,305       100   392,767       100
# 3   14,035   362,205       100   361,171       100   391,512       100
# 4   14,065   361,954       100   360,852       100   390,736       100
#
# [5 rows x 55 columns]

# %%
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
df = df.replace(to_replace='N_LAUF', value='0')
df = df.replace(to_replace='LAUF', value='1')
df = df.replace(to_replace='No Data', value='-1001')
df = df.replace(to_replace='Over Range', value='-1002')
df = df.replace(to_replace='I/O Timeout', value='-1003')
df = df.replace(to_replace='Calc Failed', value='-1004')
df = df.replace(to_replace='Error', value='-1005')
df = df.replace(to_replace='Configure', value='-1006')
df = df.replace(to_replace='Scan Off', value='-1007')
df = df.replace(to_replace='Comm Fail', value='-1008')
df = df.replace(to_replace='Shutdown', value='-1009')
df = df.replace(to_replace='NaN', value='-1010')
df = df.replace(to_replace='Bad Input', value='-1011')
df = df.replace(to_replace='Bad', value='-1012')

# %%
df_2009 = df[df['Date'].str.contains("2009")]
df_2010 = df[df['Date'].str.contains("2010")]
df_2011 = df[df['Date'].str.contains("2011")]
df_2012 = df[df['Date'].str.contains("2012")]
df_2013 = df[df['Date'].str.contains("2013")]
df_2014 = df[df['Date'].str.contains("2014")]
df_2015 = df[df['Date'].str.contains("2015")]
df_2016 = df[df['Date'].str.contains("2016")]
df_2017 = df[df['Date'].str.contains("2017")]
df_2018 = df[df['Date'].str.contains("2018")]
df_2019 = df[df['Date'].str.contains(".19")]

# %%
df_2019.shape
df.shape
# Out:
# (574005, 54)

# %%
df = df.replace(',','.', regex=True)

# %%
df.head()
# Out:
#              Date 03:I3SROE 03:T3362 03:PI3061A 03:PI3061B 03:PI3061C  \
# 0  01.01.19 00:00   890.187   77.923      3.025      3.043      3.055
# 1  01.01.19 00:10   890.262   77.893      3.024      3.043      3.053
# 2  01.01.19 00:20   890.337   77.863      3.024      3.043      3.051
# 3  01.01.19 00:30   890.294   77.833      3.023      3.043      3.051
# 4  01.01.19 00:40   890.239   77.823      3.023      3.043      3.052
#
#   03:PD3066 03:T3492 03:T3358 03:TC3550  ... 03:E3851 03:T3632 03:T3633  \
# 0     -1001   40.456   97.602   120.306  ...    0.156    16.62   16.661
# 1     -1001   40.415   97.178    120.12  ...    0.157   16.675   16.676
# 2     -1001   40.375   97.215   120.027  ...    0.158   16.711   16.726
# 3     -1001    40.41   97.602   120.114  ...    0.159   16.716   16.784
# 4     -1001    40.41   97.438   120.135  ...     0.16    16.75   16.815
#
#   03:T3634 03:FC3195 03:FV3195 03:FC3197 03:FV3197 03:FC3199 03:FV3199
# 0   13.997   358.322       100    362.52       100    392.51       100
# 1   13.985   358.897       100   362.505       100   393.009       100
# 2    14.02   358.984       100   362.305       100   392.767       100
# 3   14.035   362.205       100   361.171       100   391.512       100
# 4   14.065   361.954       100   360.852       100   390.736       100
#
# [5 rows x 54 columns]

# %%
df = df.drop(['Date'], axis = 1)
df = df.drop(['03:FV3195'], axis = 1)
df = df.drop(['03:FV3197'], axis = 1)
df = df.drop(['03:FV3199'], axis = 1)

# %%
for column in df:
    df[column] = pd.to_numeric(df[column], errors='coerce')

df.dtypes
df.shape

# %%
#get correlations of each features in dataset
corr = df.corr()
plt.subplots(figsize=(20,15))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
X, y = make_regression(n_samples=1000, n_features=50, n_informative=5, random_state=1)
model = XGBRegressor()
# fit the model
model.fit(X, y)
# get importance
importance = model.feature_importances_
# summarize feature importance
i = 0
for col,score in zip(df.columns,model.feature_importances_):
    print('Feature %d : %s = %f' % (i,col,score))
    i=i+1
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature 0 : 03:I3SROE = 0.000375
# Feature 1 : 03:T3362 = 0.001224
# Feature 2 : 03:PI3061A = 0.000627
# Feature 3 : 03:PI3061B = 0.000317
# Feature 4 : 03:PI3061C = 0.001123
# Feature 5 : 03:PD3066 = 0.000900
# Feature 6 : 03:T3492 = 0.000620
# Feature 7 : 03:T3358 = 0.000582
# Feature 8 : 03:TC3550 = 0.001795
# Feature 9 : 03:TC3550A = 0.001837
# Feature 10 : 03:FV3762 = 0.212992
# Feature 11 : 03:FC3762 = 0.001270
# Feature 12 : 03:TC3730 = 0.000378
# Feature 13 : 03:TV3730A = 0.001467
# Feature 14 : 03:TV3730B = 0.001030
# Feature 15 : 03:TV3730C = 0.000830
# Feature 16 : 03:T3731 = 0.000900
# Feature 17 : 03:P3649 = 0.000566
# Feature 18 : 03:P3065 = 0.001240
# Feature 19 : 03:LC3661 = 0.001141
# Feature 20 : 03:LI3661A = 0.001331
# Feature 21 : 03:LI3661B = 0.002121
# Feature 22 : 03:LI3661C = 0.000439
# Feature 23 : 03:YV4978 = 0.086807
# Feature 24 : 03:FC3075.OP = 0.003363
# Feature 25 : 03:FC3075 = 0.001575
# Feature 26 : 03:T3361 = 0.005241
# Feature 27 : 03:T3359 = 0.606588
# Feature 28 : 03:T3360 = 0.000340
# Feature 29 : 03:N3722_1 = 0.001144
# Feature 30 : 03:N3721_1 = 0.001863
# Feature 31 : 03:N3725_1 = 0.001347
# Feature 32 : 03:E3849 = 0.002639
# Feature 33 : 03:T3626 = 0.000285
# Feature 34 : 03:T3627 = 0.000998
# Feature 35 : 03:T3628 = 0.000940
# Feature 36 : 03:N3726_1 = 0.000606
# Feature 37 : 03:E3850 = 0.001364
# Feature 38 : 03:T3629 = 0.002089
# Feature 39 : 03:T3630 = 0.000618
# Feature 40 : 03:T3631 = 0.003345
# Feature 41 : 03:N3723_1 = 0.000996
# Feature 42 : 03:N3727_1 = 0.017324
# Feature 43 : 03:E3851 = 0.004108
# Feature 44 : 03:T3632 = 0.000334
# Feature 45 : 03:T3633 = 0.001552
# Feature 46 : 03:T3634 = 0.003341
# Feature 47 : 03:FC3195 = 0.012727
# Feature 48 : 03:FC3197 = 0.001577
# Feature 49 : 03:FC3199 = 0.001781

# %%
df['Durchsatz'] = df['03:FC3195'] + df['03:FC3197'] + df['03:FC3199']
df['Durchsatz']
# Out:
# 0         1113.352
# 1         1114.411
# 2         1114.056
# 3         1114.888
# 4         1113.542
#             ...
# 574000     932.979
# 574001     933.390
# 574002     933.553
# 574003     932.625
# 574004     944.560
# Name: Durchsatz, Length: 574005, dtype: float64

# %%
df_2019.shape
# Out:
# (70010, 54)

# %%
test = df.tail(70010)
test
# Out:
#         03:I3SROE  03:T3362  03:PI3061A  03:PI3061B  03:PI3061C  03:PD3066  \
# 503995    919.871    78.452       2.690       2.705       2.720    -1001.0
# 503996    920.013    78.423       2.687       2.702       2.716    -1001.0
# 503997    920.155    78.394       2.684       2.698       2.712    -1001.0
# 503998    920.297    78.365       2.680       2.694       2.708    -1001.0
# 503999    920.438    78.335       2.677       2.691       2.704    -1001.0
# ...           ...       ...         ...         ...         ...        ...
# 574000    749.978    73.522       2.690       2.694       2.685    -1001.0
# 574001    749.896    73.570       2.693       2.695       2.687    -1001.0
# 574002    750.080    73.618       2.696       2.697       2.689    -1001.0
# 574003    751.267    73.667       2.699       2.698       2.691    -1001.0
# 574004    755.640    73.563       2.701       2.699       2.693    -1001.0
#
#         03:T3492  03:T3358  03:TC3550  03:TC3550A  ...  03:N3723_1  \
# 503995    37.096    91.536    112.032         NaN  ...         1.0
# 503996    36.995    91.557    112.017         NaN  ...         1.0
# 503997    36.950    91.551    112.003         NaN  ...         1.0
# 503998    36.950    91.544    111.988         NaN  ...         1.0
# 503999    36.950    91.538    111.973         NaN  ...         1.0
# ...          ...       ...        ...         ...  ...         ...
# 574000    34.695    95.794    117.678         NaN  ...         1.0
# 574001    34.747    95.685    117.822         NaN  ...         1.0
# 574002    34.727    95.474    117.725         NaN  ...         1.0
# 574003    34.707    95.714    117.856         NaN  ...         1.0
# 574004    34.648    95.515    117.912         NaN  ...         1.0
#
#         03:N3727_1  03:E3851  03:T3632  03:T3633  03:T3634  03:FC3195  \
# 503995         1.0    29.802    57.056    56.971    41.973    371.995
# 503996         1.0    29.808    56.879    56.804    41.743    371.951
# 503997         1.0    29.814    56.701    56.632    41.513    371.908
# 503998         1.0    29.819    56.523    56.459    41.323    371.864
# 503999         1.0    29.825    56.345    56.287    41.178    371.820
# ...            ...       ...       ...       ...       ...        ...
# 574000         1.0    27.437    46.087    46.059    33.254    299.815
# 574001         1.0    27.446    46.111    46.074    33.265    300.061
# 574002         1.0    27.514    46.102    46.124    33.300    300.168
# 574003         1.0    27.589    46.117    46.124    33.276    300.339
# 574004         1.0    27.528    46.161    46.102    33.348    300.951
#
#         03:FC3197  03:FC3199  Durchsatz
# 503995    371.908    411.160   1155.063
# 503996    371.881    411.499   1155.331
# 503997    371.853    410.965   1154.726
# 503998    371.826    411.898   1155.588
# 503999    371.799    411.172   1154.791
# ...           ...        ...        ...
# 574000    300.258    332.906    932.979
# 574001    300.229    333.100    933.390
# 574002    300.264    333.121    933.553
# 574003    299.913    332.373    932.625
# 574004    305.107    338.502    944.560
#
# [70010 rows x 51 columns]

# %%
train = df
train.drop(df.tail(70010).index,inplace=True)
train
# Out:
#         03:I3SROE  03:T3362  03:PI3061A  03:PI3061B  03:PI3061C  03:PD3066  \
# 0         890.187    77.923       3.025       3.043       3.055    -1001.0
# 1         890.262    77.893       3.024       3.043       3.053    -1001.0
# 2         890.337    77.863       3.024       3.043       3.051    -1001.0
# 3         890.294    77.833       3.023       3.043       3.051    -1001.0
# 4         890.239    77.823       3.023       3.043       3.052    -1001.0
# ...           ...       ...         ...         ...         ...        ...
# 503990    920.346    78.597       2.707       2.723       2.740    -1001.0
# 503991    920.119    78.568       2.704       2.719       2.736    -1001.0
# 503992    919.893    78.539       2.700       2.716       2.732    -1001.0
# 503993    919.667    78.510       2.697       2.712       2.728    -1001.0
# 503994    919.729    78.481       2.694       2.709       2.724    -1001.0
#
#         03:T3492  03:T3358  03:TC3550  03:TC3550A  ...  03:N3723_1  \
# 0         40.456    97.602    120.306         NaN  ...         0.0
# 1         40.415    97.178    120.120         NaN  ...         0.0
# 2         40.375    97.215    120.027         NaN  ...         0.0
# 3         40.410    97.602    120.114         NaN  ...         0.0
# 4         40.410    97.438    120.135         NaN  ...         0.0
# ...          ...       ...        ...         ...  ...         ...
# 503990    37.412    91.705    112.106         NaN  ...         1.0
# 503991    37.342    91.601    112.091         NaN  ...         1.0
# 503992    37.272    91.496    112.076         NaN  ...         1.0
# 503993    37.203    91.481    112.062         NaN  ...         1.0
# 503994    37.096    91.508    112.047         NaN  ...         1.0
#
#         03:N3727_1  03:E3851  03:T3632  03:T3633  03:T3634  03:FC3195  \
# 0              1.0     0.156    16.620    16.661    13.997    358.322
# 1              1.0     0.157    16.675    16.676    13.985    358.897
# 2              1.0     0.158    16.711    16.726    14.020    358.984
# 3              1.0     0.159    16.716    16.784    14.035    362.205
# 4              1.0     0.160    16.750    16.815    14.065    361.954
# ...            ...       ...       ...       ...       ...        ...
# 503990         1.0    29.773    57.660    57.593    43.123    372.119
# 503991         1.0    29.779    57.544    57.469    42.893    372.096
# 503992         1.0    29.785    57.428    57.344    42.663    372.074
# 503993         1.0    29.791    57.311    57.220    42.433    372.052
# 503994         1.0    29.796    57.195    57.095    42.203    372.030
#
#         03:FC3197  03:FC3199  Durchsatz
# 0         362.520    392.510   1113.352
# 1         362.505    393.009   1114.411
# 2         362.305    392.767   1114.056
# 3         361.171    391.512   1114.888
# 4         360.852    390.736   1113.542
# ...           ...        ...        ...
# 503990    371.948    411.636   1155.703
# 503991    371.945    411.610   1155.651
# 503992    371.941    411.405   1155.420
# 503993    371.938    411.201   1155.191
# 503994    371.935    410.997   1154.962
#
# [503995 rows x 51 columns]

# %%
df.shape
# Out:
# (503995, 51)

# %%
train.head()
# Out:
#    03:I3SROE  03:T3362  03:PI3061A  03:PI3061B  03:PI3061C  03:PD3066  \
# 0    890.187    77.923       3.025       3.043       3.055    -1001.0
# 1    890.262    77.893       3.024       3.043       3.053    -1001.0
# 2    890.337    77.863       3.024       3.043       3.051    -1001.0
# 3    890.294    77.833       3.023       3.043       3.051    -1001.0
# 4    890.239    77.823       3.023       3.043       3.052    -1001.0
#
#    03:T3492  03:T3358  03:TC3550  03:TC3550A  ...  03:N3723_1  03:N3727_1  \
# 0    40.456    97.602    120.306         NaN  ...         0.0         1.0
# 1    40.415    97.178    120.120         NaN  ...         0.0         1.0
# 2    40.375    97.215    120.027         NaN  ...         0.0         1.0
# 3    40.410    97.602    120.114         NaN  ...         0.0         1.0
# 4    40.410    97.438    120.135         NaN  ...         0.0         1.0
#
#    03:E3851  03:T3632  03:T3633  03:T3634  03:FC3195  03:FC3197  03:FC3199  \
# 0     0.156    16.620    16.661    13.997    358.322    362.520    392.510
# 1     0.157    16.675    16.676    13.985    358.897    362.505    393.009
# 2     0.158    16.711    16.726    14.020    358.984    362.305    392.767
# 3     0.159    16.716    16.784    14.035    362.205    361.171    391.512
# 4     0.160    16.750    16.815    14.065    361.954    360.852    390.736
#
#    Durchsatz
# 0   1113.352
# 1   1114.411
# 2   1114.056
# 3   1114.888
# 4   1113.542
#
# [5 rows x 51 columns]

# %%
test = test.drop(['03:FC3195'], axis = 1)
test = test.drop(['03:FC3197'], axis = 1)
test = test.drop(['03:FC3199'], axis = 1)

# %%
train = train.drop(['03:FC3195'], axis = 1)
train = train.drop(['03:FC3197'], axis = 1)
train = train.drop(['03:FC3199'], axis = 1)

# %%
test.head()
# Out:
#         03:I3SROE  03:T3362  03:PI3061A  03:PI3061B  03:PI3061C  03:PD3066  \
# 503995    919.871    78.452       2.690       2.705       2.720    -1001.0
# 503996    920.013    78.423       2.687       2.702       2.716    -1001.0
# 503997    920.155    78.394       2.684       2.698       2.712    -1001.0
# 503998    920.297    78.365       2.680       2.694       2.708    -1001.0
# 503999    920.438    78.335       2.677       2.691       2.704    -1001.0
#
#         03:T3492  03:T3358  03:TC3550  03:TC3550A  ...  03:T3629  03:T3630  \
# 503995    37.096    91.536    112.032         NaN  ...    28.249    28.583
# 503996    36.995    91.557    112.017         NaN  ...    28.129    28.496
# 503997    36.950    91.551    112.003         NaN  ...    28.010    28.409
# 503998    36.950    91.544    111.988         NaN  ...    27.890    28.322
# 503999    36.950    91.538    111.973         NaN  ...    27.773    28.235
#
#         03:T3631  03:N3723_1  03:N3727_1  03:E3851  03:T3632  03:T3633  \
# 503995    26.741         1.0         1.0    29.802    57.056    56.971
# 503996    26.668         1.0         1.0    29.808    56.879    56.804
# 503997    26.594         1.0         1.0    29.814    56.701    56.632
# 503998    26.521         1.0         1.0    29.819    56.523    56.459
# 503999    26.448         1.0         1.0    29.825    56.345    56.287
#
#         03:T3634  Durchsatz
# 503995    41.973   1155.063
# 503996    41.743   1155.331
# 503997    41.513   1154.726
# 503998    41.323   1155.588
# 503999    41.178   1154.791
#
# [5 rows x 48 columns]

# %%
test.isna().sum()
test = test.drop(['03:TC3550A'], axis = 1)
test = test.drop(['03:YV4978'], axis = 1)

# %%
test.dropna()
# Out:
#         03:I3SROE  03:T3362  03:PI3061A  03:PI3061B  03:PI3061C  03:PD3066  \
# 503995    919.871    78.452       2.690       2.705       2.720    -1001.0
# 503996    920.013    78.423       2.687       2.702       2.716    -1001.0
# 503997    920.155    78.394       2.684       2.698       2.712    -1001.0
# 503998    920.297    78.365       2.680       2.694       2.708    -1001.0
# 503999    920.438    78.335       2.677       2.691       2.704    -1001.0
# ...           ...       ...         ...         ...         ...        ...
# 574000    749.978    73.522       2.690       2.694       2.685    -1001.0
# 574001    749.896    73.570       2.693       2.695       2.687    -1001.0
# 574002    750.080    73.618       2.696       2.697       2.689    -1001.0
# 574003    751.267    73.667       2.699       2.698       2.691    -1001.0
# 574004    755.640    73.563       2.701       2.699       2.693    -1001.0
#
#         03:T3492  03:T3358  03:TC3550  03:FV3762  ...  03:T3629  03:T3630  \
# 503995    37.096    91.536    112.032     48.615  ...    28.249    28.583
# 503996    36.995    91.557    112.017     48.644  ...    28.129    28.496
# 503997    36.950    91.551    112.003     48.673  ...    28.010    28.409
# 503998    36.950    91.544    111.988     48.702  ...    27.890    28.322
# 503999    36.950    91.538    111.973     48.731  ...    27.773    28.235
# ...          ...       ...        ...        ...  ...       ...       ...
# 574000    34.695    95.794    117.678     38.428  ...    42.624    42.860
# 574001    34.747    95.685    117.822     38.568  ...    42.689    42.933
# 574002    34.727    95.474    117.725     38.561  ...    42.764    43.006
# 574003    34.707    95.714    117.856     38.576  ...    42.841    43.040
# 574004    34.648    95.515    117.912     38.734  ...    42.885    43.090
#
#         03:T3631  03:N3723_1  03:N3727_1  03:E3851  03:T3632  03:T3633  \
# 503995    26.741         1.0         1.0    29.802    57.056    56.971
# 503996    26.668         1.0         1.0    29.808    56.879    56.804
# 503997    26.594         1.0         1.0    29.814    56.701    56.632
# 503998    26.521         1.0         1.0    29.819    56.523    56.459
# 503999    26.448         1.0         1.0    29.825    56.345    56.287
# ...          ...         ...         ...       ...       ...       ...
# 574000    30.950         1.0         1.0    27.437    46.087    46.059
# 574001    30.971         1.0         1.0    27.446    46.111    46.074
# 574002    30.939         1.0         1.0    27.514    46.102    46.124
# 574003    30.907         1.0         1.0    27.589    46.117    46.124
# 574004    30.875         1.0         1.0    27.528    46.161    46.102
#
#         03:T3634  Durchsatz
# 503995    41.973   1155.063
# 503996    41.743   1155.331
# 503997    41.513   1154.726
# 503998    41.323   1155.588
# 503999    41.178   1154.791
# ...          ...        ...
# 574000    33.254    932.979
# 574001    33.265    933.390
# 574002    33.300    933.553
# 574003    33.276    932.625
# 574004    33.348    944.560
#
# [70009 rows x 46 columns]

# %%
train.isna().sum()
train = train.drop(['03:TC3550A'], axis = 1)
train = train.drop(['03:YV4978'], axis = 1)

# %%
train.head()
# Out:
#    03:I3SROE  03:T3362  03:PI3061A  03:PI3061B  03:PI3061C  03:PD3066  \
# 0    890.187    77.923       3.025       3.043       3.055    -1001.0
# 1    890.262    77.893       3.024       3.043       3.053    -1001.0
# 2    890.337    77.863       3.024       3.043       3.051    -1001.0
# 3    890.294    77.833       3.023       3.043       3.051    -1001.0
# 4    890.239    77.823       3.023       3.043       3.052    -1001.0
#
#    03:T3492  03:T3358  03:TC3550  03:FV3762  ...  03:T3629  03:T3630  \
# 0    40.456    97.602    120.306     45.113  ...    42.798    43.061
# 1    40.415    97.178    120.120     44.936  ...    42.860    43.125
# 2    40.375    97.215    120.027     44.697  ...    42.903    43.132
# 3    40.410    97.602    120.114     44.611  ...    42.917    43.146
# 4    40.410    97.438    120.135     44.707  ...    42.945    43.172
#
#    03:T3631  03:N3723_1  03:N3727_1  03:E3851  03:T3632  03:T3633  03:T3634  \
# 0    31.555         0.0         1.0     0.156    16.620    16.661    13.997
# 1    31.590         0.0         1.0     0.157    16.675    16.676    13.985
# 2    31.625         0.0         1.0     0.158    16.711    16.726    14.020
# 3    31.660         0.0         1.0     0.159    16.716    16.784    14.035
# 4    31.668         0.0         1.0     0.160    16.750    16.815    14.065
#
#    Durchsatz
# 0   1113.352
# 1   1114.411
# 2   1114.056
# 3   1114.888
# 4   1113.542
#
# [5 rows x 46 columns]

# %%
train_X = train.drop(['Durchsatz'], axis = 1)
train_y = train['Durchsatz']
test_X = test.drop(['Durchsatz'], axis = 1)
test_y = test['Durchsatz']

# %%
test_y.shape
# Out:
# (70010,)

# %%
train_X.dropna(inplace=True)
train_y.dropna(inplace=True)
test_X.dropna(inplace=True)
test_y.dropna(inplace=True)

# %%
train_X.shape
# Out:
# (503986, 45)

# %%
train_y.shape
# Out:
# (503986,)

# %%
test_X.shape
# Out:
# (70009, 45)

# %%
test_y.shape
# Out:
# (70009,)

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
#Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(train_X, train_y)

# Make predictions using the testing set
y_pred = regr.predict(test_X)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(test_y, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(test_y, y_pred))

# Plot outputs
#plt.scatter(test_y, y_pred,  color='black')
#plt.subplots(figsize=(20,15))

fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
axs[0].plot(test_y)
axs[1].plot(y_pred)


#plt.plot(test_y, color='blue')
#plt.plot(y_pred, color='skyblue')
plt.show()
# Out:
# Coefficients:
#  [ 1.46286556e+00  7.10833096e-01 -1.31526984e+01  1.20996854e+01
#  -1.03017243e-01 -2.81192434e+00 -3.57210424e-01 -8.72626229e-03
#  -4.60906515e-01  8.23815580e-02  5.49632502e-03  3.41162083e-01
#  -3.46094431e-01 -5.57581105e-01  9.89788639e-01  3.80621109e-01
#   7.32504293e-01  7.15844909e-02 -4.04433886e-01  5.59598244e-01
#  -2.07595266e-02  6.92062812e-02  1.88344960e+00 -1.50479980e-01
#   7.60611489e-01  8.89476105e-01  1.29574112e-02 -4.07252592e-01
#   2.35507050e-01 -1.14315337e+01 -5.02578817e-02 -6.93390229e-01
#   1.33644301e+00  2.38899913e-01 -2.63339004e+01 -1.97878819e-01
#   1.68841116e+00 -4.33723420e-01 -1.78526087e+00 -4.31983877e-01
#   3.83434753e+01 -2.70116970e-01 -5.20240715e-01  1.84750809e+00
#  -1.36078208e+00]
# Mean squared error: 3655.52
# Coefficient of determination: 0.89

# %%
test_y.head()
# Out:
# 503995    1155.063
# 503996    1155.331
# 503997    1154.726
# 503998    1155.588
# 503999    1154.791
# Name: Durchsatz, dtype: float64

# %%
test = pd.DataFrame()

# %%
test['predictions'] = y_pred.tolist()

# %%
print(str(y_pred) + '    ' + str(test_y))
# Out:
# [1146.24338021 1148.7631605  1149.61571828 ...  925.02672645  927.00841749
#   932.77987575]    503995    1155.063
# 503996    1155.331
# 503997    1154.726
# 503998    1155.588
# 503999    1154.791
#             ...
# 574000     932.979
# 574001     933.390
# 574002     933.553
# 574003     932.625
# 574004     944.560
# Name: Durchsatz, Length: 70009, dtype: float64

# %%
abweichungen = test_y - y_pred

# %%
abweichungen
# Out:
# 503995     8.819620
# 503996     6.567839
# 503997     5.110282
# 503998    -1.626405
# 503999    -4.912857
#             ...
# 574000     7.789290
# 574001     8.406916
# 574002     8.526274
# 574003     5.616583
# 574004    11.780124
# Name: Durchsatz, Length: 70009, dtype: float64

# %%
plt.plot(abweichungen)
